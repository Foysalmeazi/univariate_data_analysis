# %% [markdown]
# ##### 1. Import necessary libraries

# %%
# %pip install -q -u numpy pandas matplotlib seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Usage:
#   c:\CDU Research Resourses\Machine Learning Bootcamp_Siddhardhan\Exploratory Data Analysis\.venv\Scripts\python.exe -m pip install [options] <requirement specifier> [package-index-options] ...
#   c:\CDU Research Resourses\Machine Learning Bootcamp_Siddhardhan\Exploratory Data Analysis\.venv\Scripts\python.exe -m pip install [options] -r <requirements file> [package-index-options] ...
#   c:\CDU Research Resourses\Machine Learning Bootcamp_Siddhardhan\Exploratory Data Analysis\.venv\Scripts\python.exe -m pip install [options] [-e] <vcs project url> ...
#   c:\CDU Research Resourses\Machine Learning Bootcamp_Siddhardhan\Exploratory Data Analysis\.venv\Scripts\python.exe -m pip install [options] [-e] <local project path> ...
#   c:\CDU Research Resourses\Machine Learning Bootcamp_Siddhardhan\Exploratory Data Analysis\.venv\Scripts\python.exe -m pip install [options] <archive url/path> ...
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(0)
pd.set_option('display.max_columns', 50)
sns.set_style('whitegrid')

# %% [markdown]
# ##### 2. Load dataset

# %%
# Load the Titanic dataset
data = sns.load_dataset('titanic')

# Look at the first 5 rows
display(data.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
data.shape
# Out:
# (891, 15)

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Identify numerical and categorical columns
numerical_cols = ['age', 'fare', 'sibsp', 'parch']  # Explicitly specify numerical columns
categorical_cols = ['survived', 'pclass', 'sex', 'embarked', 'class', 'who', 'adult_male', 'deck','embark_town', 'alone']

print("Categorical Columns:", categorical_cols)
print("Numerical Columns:", numerical_cols)
# Out:
# Categorical Columns: ['survived', 'pclass', 'sex', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alone']
# Numerical Columns: ['age', 'fare', 'sibsp', 'parch']

# %% [markdown]
# #### 3. Numerical Features Analysis

# %%
data[numerical_cols].head()
# Out:
#     age     fare  sibsp  parch
# 0  22.0   7.2500      1      0
# 1  38.0  71.2833      1      0
# 2  26.0   7.9250      0      0
# 3  35.0  53.1000      1      0
# 4  35.0   8.0500      0      0

# %% [markdown]
# 3.1 Summary Statistics

# %%
data[numerical_cols].describe()
# Out:
#               age        fare       sibsp       parch
# count  714.000000  891.000000  891.000000  891.000000
# mean    29.699118   32.204208    0.523008    0.381594
# std     14.526497   49.693429    1.102743    0.806057
# min      0.420000    0.000000    0.000000    0.000000
# 25%     20.125000    7.910400    0.000000    0.000000
# 50%     28.000000   14.454200    0.000000    0.000000
# 75%     38.000000   31.000000    1.000000    0.000000
# max     80.000000  512.329200    8.000000    6.000000

# %% [markdown]
# 3.2 Mean

# %%
# Mean

print('Numerical Columns Mean:')
print(data[numerical_cols].mean())

print('-'*50)

print('Numerical Columns Median:')
print(data[numerical_cols].median())

print('Numerical Columns Mode:')
print(data[numerical_cols].mode().iloc[0])
# Out:
# Numerical Columns Mean:
# age      29.699118
# fare     32.204208
# sibsp     0.523008
# parch     0.381594
# dtype: float64
# --------------------------------------------------
# Numerical Columns Median:
# age      28.0000
# fare     14.4542
# sibsp     0.0000
# parch     0.0000
# dtype: float64
# Numerical Columns Mode:
# age      24.00
# fare      8.05
# sibsp     0.00
# parch     0.00
# Name: 0, dtype: float64

# %% [markdown]
# 3.3 Varience and Standard Deviation

# %%
#Variance
print('Numerical Columns Variance:')
print(data[numerical_cols].var())

# Standard Deviation
print('Numerical Columns Standard Deviation:')
print(data[numerical_cols].std())
# Out:
# Numerical Columns Variance:
# age       211.019125
# fare     2469.436846
# sibsp       1.216043
# parch       0.649728
# dtype: float64
# Numerical Columns Standard Deviation:
# age      14.526497
# fare     49.693429
# sibsp     1.102743
# parch     0.806057
# dtype: float64

# %% [markdown]
# 3.4 Skewness and Kurtosis

# %%
print('\n Skewness of Numerical Data')
print(data[numerical_cols].skew())
print('\n Kurtosis of Numerical Data')
print(data[numerical_cols].kurt())
# Out:
#  Skewness of Numerical Data
# age      0.389108
# fare     4.787317
# sibsp    3.695352
# parch    2.749117
# dtype: float64
#
#  Kurtosis of Numerical Data
# age       0.178274
# fare     33.398141
# sibsp    17.880420
# parch     9.778125
# dtype: float64

# %% [markdown]
# 3.5 Histograms

# %%
plt.figure(figsize=(5,3))
sns.histplot(data['age'], bins=30, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')   
plt.ylabel('Frequency')
plt.show()

# %%
# Numerical Columns Histograms
for col in numerical_cols:
    plt.figure(figsize=(5,3))
    sns.histplot(data[col], bins=30, kde=True)
    plt.title(f'Distribution of {col.capitalize()}')
    plt.xlabel(col.capitalize())   
    plt.ylabel('Frequency')
    plt.show()

# %%
# Numerical Columns Boxplots
for col in numerical_cols:
    plt.figure(figsize=(5,3))
    sns.boxplot(x=data[col])
    plt.title(f'Boxplot of {col.capitalize()}')
    plt.ylabel(col.capitalize())
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# #### 4. Categorical Features Analysis

# %%
data[categorical_cols].head()
# Out:
#    survived  pclass     sex embarked  class    who  adult_male deck  \
# 0         0       3    male        S  Third    man        True  NaN
# 1         1       1  female        C  First  woman       False    C
# 2         1       3  female        S  Third  woman       False  NaN
# 3         1       1  female        S  First  woman       False    C
# 4         0       3    male        S  Third    man        True  NaN
#
#    embark_town  alone
# 0  Southampton  False
# 1    Cherbourg  False
# 2  Southampton   True
# 3  Southampton  False
# 4  Southampton   True

# %% [markdown]
# 4.1 Frequency Table

# %%
for col in categorical_cols:
    print(f'Value Counts (Frequency Table) for {col.capitalize()}:')
    print(data[col].value_counts())
    print('-'*50)
    print(f'Value Counts (Frequency Table) for {col.capitalize()} in percentage:')
    print(data[col].value_counts(normalize=True))


data['pclass'].value_counts(normalize=True)
# Out:
# Value Counts (Frequency Table) for Survived:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64
# --------------------------------------------------
# Value Counts (Frequency Table) for Survived in percentage:
# survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64
# Value Counts (Frequency Table) for Pclass:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# --------------------------------------------------
# Value Counts (Frequency Table) for Pclass in percentage:
# pclass
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: proportion, dtype: float64
# Value Counts (Frequency Table) for Sex:
# sex
# male      577
# female    314
# Name: count, dtype: int64
# --------------------------------------------------
# Value Counts (Frequency Table) for Sex in percentage:
# sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64
# Value Counts (Frequency Table) for Embarked:
# embarked
# S    644
# C    168
# ...

# %% [markdown]
# 4.2 Countplot

# %%
for col in categorical_cols:
    plt.figure(figsize=(5,3))
    sns.countplot(x=data[col])
    plt.title(f'Count Plot of {col.capitalize()}')
    plt.xlabel(col.capitalize())
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()
